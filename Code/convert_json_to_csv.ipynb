# %%
import pandas as pd
import json
data=[]
with open('football_video.json', encoding="utf8") as data_file:
    for line in data_file:
        data.append(json.loads(line))
df=pd.DataFrame(data,columns=['text'])
df.to_csv('commentData.csv',index=None, header=None)
df
# Out:
#                                                  text
# 0   Btsport should use this when the final comes o...
# 1   Can anyone tell me the first Track of the Video?😍
# 2                                                COYR
# 3                                        Music please
# 4   I am a liverpool fan i believe well  beat tott...
# 5                                        Great video😍
# 6                        kLOPP YWNWA the leag is ours
# 7   Wow! You're fuckin good bra. Start working on ...
# 8   I’m still having goosebumps watching the last ...
# 9   Daaamn am not even a Liverpool fan....and I do...
# 10                        I cut this onions hahaha 😉😂
# 11  We'll never let you walk alone, always support...
# 12                                3:54 gave me chills
# 13                     Anyone know the music at 5:55?
# 14  Liverpool doing the job but now we wait the fi...
# 15                                            GINI ON
# ...
